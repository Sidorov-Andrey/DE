# %% [markdown]
# # Игра "Угадай число"

# %% [markdown]
# ###1. При угадывании алгоритм учитывает информацию о том, больше ли случайное число или меньше нужного нам.

# %%
from game_v3 import score_game
from game_v3 import random_predict

score_game(random_predict)

# %% [markdown]
# ###2. Угадываем методом дихотомии

# %%
from game_v4 import score_game
from game_v4 import random_predict

score_game(random_predict)
